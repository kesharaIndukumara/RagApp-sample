# %% [markdown]
# ### Data Injection

# %%
from langchain_core.documents import Document

# %%
doc=Document(
    page_content="This is a sample document.",
    metadata={
        "source": "example.txt",
        "page": 1,
        "author": "John Doe",
    }
)
doc
# Out:
# Document(metadata={'source': 'example.txt', 'page': 1, 'author': 'John Doe'}, page_content='This is a sample document.')

# %%
## Create a simple txt file

import os
os.makedirs("../data/text_files", exist_ok=True)

# %%
sample_text = {
    "../data/text_files/python_intro.txt": "This is a sample text file.\nIt contains multiple lines of text.\nThis is the third line.",
}

for filepath, content in sample_text.items():
    with open(filepath, 'w',encoding='utf-8') as f:
        f.write(content)

print("Sample text files created.")
# Out:
# Sample text files created.

# %%
# Install/upgrade langchain in a cross-platform way (uses the running Python executable)
import sys, subprocess
subprocess.check_call([sys.executable, "-m", "pip", "install", "--upgrade", "langchain"])
print('langchain installed/upgraded')

# %%
### TextLoader

from langchain_community.document_loaders import TextLoader

loader=TextLoader("../data/text_files/python_intro.txt", encoding="utf-8")
document = loader.load()

print(document)
# Out:
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content='This is a sample text file.\nIt contains multiple lines of text.\nThis is the third line.')]

# %%
### Directory Loader

from langchain_community.document_loaders import DirectoryLoader

## load all the text files in the directory

dir_loader=DirectoryLoader(
    "../data/text_files",
    glob="**/*.txt",
    loader_cls=TextLoader,
    loader_kwargs={'encoding':'utf-8'},
    show_progress=False
)

documents=dir_loader.load()
documents
# Out:
# [Document(metadata={'source': '..\\data\\text_files\\python_intro.txt'}, page_content='This is a sample text file.\nIt contains multiple lines of text.\nThis is the third line.')]

# %%
from langchain_community.document_loaders import PyPDFLoader, PyMuPDFLoader

dir_loader=DirectoryLoader(
    "../data/pdf",
    glob="**/*.pdf",
    loader_cls=PyMuPDFLoader,
    show_progress=False
)

pdf_documents = dir_loader.load()
pdf_documents
# Out:
# [Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-05-01T13:31:43+05:30', 'source': '..\\data\\pdf\\Programme-360.pdf', 'file_path': '..\\data\\pdf\\Programme-360.pdf', 'total_pages': 1, 'format': 'PDF 1.7', 'title': '', 'author': 'Keshara Indukumara', 'subject': '', 'keywords': '', 'moddate': '2025-05-01T13:31:43+05:30', 'trapped': '', 'modDate': "D:20250501133143+05'30'", 'creationDate': "D:20250501133143+05'30'", 'page': 0}, page_content='Programme 360 - President \n \nDerana-Stores \n \nG4 micRack [ Booster x2 with Anterna ] \nXLR ch5 Snake \nYbox-[ Capsulex2 with Dynamic_mic x1 ] \nXLR x3 \nXLR_Converter- Male to Standerd x2 \nBatteries \n \nCommunication_Stanby - Dynamic_mic x1, PlugOn x1, ReciverBodyPack x1, spiral_earpiece x1 \n \nPresident-Media \nAudio-Console \nAudio-Monitor \nHeadphone  \nPresenter Communication set \nXLR \nMonitor power codes x3 \nPower Extension code x2'),
# ...

# %%
type(pdf_documents[0])
# Out:
# langchain_core.documents.base.Document

# %% [markdown]
# 49.00
